# %%
#importing labraries
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

import scipy.stats as stats
import warnings
warnings.filterwarnings("ignore")

# %%
#reading the csv file
haberdata = pd.read_csv("Documents/PYTHON_FILES_FROM_JUPITER_NOTEBOOK/haberman/haberman_dataset/haberman.csv")

# %%
haberdata
# Out:
#      age  year  nodes  status
# 0     30    64      1       1
# 1     30    62      3       1
# 2     30    65      0       1
# 3     31    59      2       1
# 4     31    65      4       1
# ..   ...   ...    ...     ...
# 301   75    62      1       1
# 302   76    67      0       1
# 303   77    65      3       1
# 304   78    65      1       2
# 305   83    58      2       2
#
# [306 rows x 4 columns]

# %% [markdown]
# # Analyzing the Data

# %%
haberdata.head(10)
# Out:
#    age  year  nodes  status
# 0   30    64      1       1
# 1   30    62      3       1
# 2   30    65      0       1
# 3   31    59      2       1
# 4   31    65      4       1
# 5   33    58     10       1
# 6   33    60      0       1
# 7   34    59      0       2
# 8   34    66      9       2
# 9   34    58     30       1

# %%
#printing the columns
haberdata.columns
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
haberdata['status'].value_counts()
# Out:
# 1    225
# 2     81
# Name: status, dtype: int64

# %%
haberdata.shape
# Out:
# (306, 4)

# %%
#brief info about the dataset
haberdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     306 non-null    int64
#  1   year    306 non-null    int64
#  2   nodes   306 non-null    int64
#  3   status  306 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
haberdata.describe()
# Out:
#               age        year       nodes      status
# count  306.000000  306.000000  306.000000  306.000000
# mean    52.457516   62.852941    4.026144    1.264706
# std     10.803452    3.249405    7.189654    0.441899
# min     30.000000   58.000000    0.000000    1.000000
# 25%     44.000000   60.000000    0.000000    1.000000
# 50%     52.000000   63.000000    1.000000    1.000000
# 75%     60.750000   65.750000    4.000000    2.000000
# max     83.000000   69.000000   52.000000    2.000000

# %%
#mapping the values of 1 and 2 to yes and no respectively and
#printing the first 5 records from the dataset.

haberdata['status'] = haberdata['status'].map({1:'yes', 2:'no'})
haberdata.head()
# Out:
#    age  year  nodes status
# 0   30    64      1    yes
# 1   30    62      3    yes
# 2   30    65      0    yes
# 3   31    59      2    yes
# 4   31    65      4    yes

# %% [markdown]
# Bivariate Analysis

# %%
haberdata.plot(kind = "scatter" , x = 'age' , y = 'nodes')
plt.title('Scatter Plot of age vs nodes')
plt.show()

# %%
sns.set_style("whitegrid");
sns.FacetGrid(haberdata, hue="status", height=5)\
.map(plt.scatter, "age", "nodes") \
.add_legend()
plt.title('Scatter Plot Using Seaborn of age vs nodes')
plt.show()

# %%
#3D Pair Plot
sns.set_style("whitegrid");
sns.pairplot(haberdata,hue ='status',height = 3)
plt.show()

# %%
# Box-Plot
sns.boxplot(x='status',y='age', data=haberdata)
plt.title("Box showing age vs status")
plt.show()

# %%
# Box-Plot
sns.boxplot(x='status',y='nodes', data=haberdata)
plt.legend
plt.title("Box showing age vs nodes")
plt.show()

# %%
# A violin plot 
sns.violinplot(x='status',y='age', data=haberdata, size=8)
plt.show()

# %%
# A violin plot 
sns.violinplot(x='age',y='nodes', data=haberdata, height=8)
plt.show()

# %%
#sns.set_style("whitegrid");
sns.FacetGrid(haberdata, hue="status", height=5)\
.map(sns.distplot, "age") \
.add_legend()
plt.title('Histogram of age')
plt.show()

# %%
sns.FacetGrid(haberdata,hue='status',height = 5)\
.map(sns.distplot,'year')\
.add_legend();
plt.title('Histogram of year')
plt.show()

# %%
# A violin plot 
sns.violinplot(x='status',y='nodes', data=haberdata, size=8)
plt.legend
plt.title("Violin Plot")
plt.show()
