# %%
#Importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import bokeh as bk
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
#Importing matplotlib module to keep charts in this notebook
import matplotlib.pyplot as plt
# %matplotlib inline
#Importing module to overwrite any warnings for a clean presentation
import warnings
warnings.filterwarnings('ignore')

# %%
#Creating column names for dataset
column_names = ['Index', 'Country', 'Description', 'Designation', 'Points', 
                'Price', 'Province', 'Region_1', 'Region_2', 'Variety', 'Winery']

# %%
#Reading CSV file using the column_names in the names parameter
reviews_df = pd.read_csv('Documents/winemag-data_first150k.csv', sep = ',', header = 1, 
                        names = column_names, index_col = 0)
reviews_df
# Out:
#        Country                                        Description  \
# Index
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# 5        Spain  Deep, dense and pure from the opening bell, th...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  Designation  Points  Price  \
# Index
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# 5                                  Numanthia      95   73.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   Province           Region_1           Region_2  \
# Index
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# 5           Northern Spain               Toro                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    Variety                   Winery
# Index
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# 5            Tinta de Toro                Numanthia
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150929 rows x 10 columns]

# %%
#Getting the sahpe of the dataframe
reviews_df.shape
# Out:
# (150929, 10)

# %%
#Displaying the first 10 records
reviews_df.head(10)
# Out:
#       Country                                        Description  \
# Index
# 1       Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2          US  Mac Watson honors the memory of a wine once ma...
# 3          US  This spent 20 months in 30% new French oak, an...
# 4      France  This is the top wine from La Bégude, named aft...
# 5       Spain  Deep, dense and pure from the opening bell, th...
# 6       Spain  Slightly gritty black-fruit aromas include a s...
# 7       Spain  Lush cedary black-fruit aromas are luxe and of...
# 8          US  This re-named vineyard was formerly bottled as...
# 9          US  The producer sources from two blocks of the vi...
# 10      Italy  Elegance, complexity and structure come togeth...
#
#                                 Designation  Points  Price  \
# Index
# 1      Carodorum Selección Especial Reserva      96  110.0
# 2             Special Selected Late Harvest      96   90.0
# 3                                   Reserve      96   65.0
# 4                                La Brûlade      95   66.0
# 5                                 Numanthia      95   73.0
# 6                                 San Román      95   65.0
# 7                   Carodorum Único Crianza      95  110.0
# 8                                    Silice      95   65.0
# 9                      Gap's Crown Vineyard      95   60.0
# 10                       Ronco della Chiesa      95   80.0
#
#                  Province            Region_1           Region_2  \
# Index
# 1          Northern Spain                Toro                NaN
# 2              California      Knights Valley             Sonoma
# 3                  Oregon   Willamette Valley  Willamette Valley
# 4                Provence              Bandol                NaN
# 5          Northern Spain                Toro                NaN
# 6          Northern Spain                Toro                NaN
# 7          Northern Spain                Toro                NaN
# 8                  Oregon  Chehalem Mountains  Willamette Valley
# 9              California        Sonoma Coast             Sonoma
# 10     Northeastern Italy              Collio                NaN
#
#                   Variety                   Winery
# Index
# 1           Tinta de Toro  Bodega Carmen Rodríguez
# 2         Sauvignon Blanc                 Macauley
# 3              Pinot Noir                    Ponzi
# 4      Provence red blend     Domaine de la Bégude
# 5           Tinta de Toro                Numanthia
# 6           Tinta de Toro                 Maurodos
# 7           Tinta de Toro  Bodega Carmen Rodríguez
# 8              Pinot Noir                Bergström
# 9              Pinot Noir                Blue Farm
# 10               Friulano         Borgo del Tiglio

# %%
#Displaying info about the dataset
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150929 entries, 1 to 150929
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Country      150924 non-null  object
#  1   Description  150929 non-null  object
#  2   Designation  105194 non-null  object
#  3   Points       150929 non-null  int64
#  4   Price        137234 non-null  float64
#  5   Province     150924 non-null  object
#  6   Region_1     125869 non-null  object
#  7   Region_2     60952 non-null   object
#  8   Variety      150929 non-null  object
#  9   Winery       150929 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 12.7+ MB

# %%
#Displaying the datatypes in the dataset
reviews_df.dtypes
# Out:
# Country         object
# Description     object
# Designation     object
# Points           int64
# Price          float64
# Province        object
# Region_1        object
# Region_2        object
# Variety         object
# Winery          object
# dtype: object

# %%
#Checking to see if the dataset has null values
reviews_df.isnull().any() #True if column has null values, False if no null values present
# Out:
# Country         True
# Description    False
# Designation     True
# Points         False
# Price           True
# Province        True
# Region_1        True
# Region_2        True
# Variety        False
# Winery         False
# dtype: bool

# %%
#Displaying number of null values per column
reviews_df.isnull().sum()
# Out:
# Country            5
# Description        0
# Designation    45735
# Points             0
# Price          13695
# Province           5
# Region_1       25060
# Region_2       89977
# Variety            0
# Winery             0
# dtype: int64

# %%
#Displaying the null values in the Country column
reviews_df[reviews_df.Country.isnull()]
# Out:
#        Country                                        Description  \
# Index
# 1133       NaN  Delicate white flowers and a spin of lemon pee...
# 1440       NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 68226      NaN  From first sniff to last, the nose never makes...
# 113016     NaN  From first sniff to last, the nose never makes...
# 135696     NaN  From first sniff to last, the nose never makes...
#
#          Designation  Points  Price Province Region_1 Region_2     Variety  \
# Index
# 1133       Askitikos      90   17.0      NaN      NaN      NaN   Assyrtiko
# 1440            Shah      90   30.0      NaN      NaN      NaN   Red Blend
# 68226   Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
#
#            Winery
# Index
# 1133     Tsililis
# 1440    Büyülübağ
# 68226     Chilcas
# 113016    Chilcas
# 135696    Chilcas

# %%
#Confirming dataframe shape
reviews_df.shape
# Out:
# (150929, 10)

# %%
#Deleting/dropping the null value records for Country
reviews_df = reviews_df.dropna(how = 'any', subset = ['Country'])

# %%
#Confirming drop and displaying new shape of dataframe
reviews_df.shape
# Out:
# (150924, 10)

# %%
reviews_df[reviews_df.Country.isnull()]
# Out:
# Empty DataFrame
# Columns: [Country, Description, Designation, Points, Price, Province, Region_1, Region_2, Variety, Winery]
# Index: []

# %%
reviews_df.isnull().sum()
# Out:
# Country            0
# Description        0
# Designation    45735
# Points             0
# Price          13695
# Province           0
# Region_1       25055
# Region_2       89972
# Variety            0
# Winery             0
# dtype: int64

# %%
#Calculating the percentage of remaining records if missing prices are dropped
total_records = len(reviews_df)
missing_prices = reviews_df['Price'].isnull().sum()
missing_ratio = 100 - ((missing_prices/total_records)*100)
print('Missing prices: {}'.format(missing_prices) + '\n' +
     'Total records: {}'.format(total_records) + '\n' +
     'Percentage remaining: {:.2f}%'.format(missing_ratio))
# Out:
# Missing prices: 13695
# Total records: 150924
# Percentage remaining: 90.93%

# %%
#Dropping records with null values in the 'Price' column
reviews_df = reviews_df.dropna(how = 'any', subset = ['Price'])

# %%
#Confirming new shape  and displaying dataframe
reviews_df.shape
# Out:
# (137229, 10)

# %%
reviews_df[reviews_df.Price.isnull()]
# Out:
# Empty DataFrame
# Columns: [Country, Description, Designation, Points, Price, Province, Region_1, Region_2, Variety, Winery]
# Index: []

# %%
#Finding number of rows that have zero null values in any column
complete = reviews_df[reviews_df.isnull().any(axis = 1)].shape
print('Records without null values:\n(rows, columns)\t{}'.format(complete))
# Out:
# Records without null values:
# (rows, columns)	(97989, 10)

# %%
#Calculating the percentage of fully complete rows in the dataset
complete_rows = int(complete[0])
total_rows = len(reviews_df)

completion_ratio = ((complete_rows/total_rows)*100)
print('Total complete records: \t\t{}'.format(complete_rows) +
     '\nTotal records: \t\t\t\t{}'.format(total_rows) +
     '\nCompletion ratio: \t\t\t{:.2f}%'.format(completion_ratio))
# Out:
# Total complete records: 		97989
# Total records: 				137229
# Completion ratio: 			71.41%

# %% [markdown]
# # Analyzing the DataFrame

# %%
#Displaying the descriptive stats of the numerical data in dataframe
reviews_df.describe()
# Out:
#               Points          Price
# count  137229.000000  137229.000000
# mean       87.787975      33.130548
# std         3.221507      36.319116
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %%
#Performing descriptive stat analysis on categorical data in the dataframe
reviews_df['Country'].describe()
# Out:
# count     137229
# unique        46
# top           US
# freq       62138
# Name: Country, dtype: object

# %%
reviews_df['Designation'].describe()
# Out:
# count       94918
# unique      28343
# top       Reserve
# freq         2704
# Name: Designation, dtype: object

# %%
reviews_df['Points'].describe()
# Out:
# count    137229.000000
# mean         87.787975
# std           3.221507
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          90.000000
# max         100.000000
# Name: Points, dtype: float64

# %%
reviews_df['Price'].describe()
# Out:
# count    137229.000000
# mean         33.130548
# std          36.319116
# min           4.000000
# 25%          16.000000
# 50%          24.000000
# 75%          40.000000
# max        2300.000000
# Name: Price, dtype: float64

# %%
reviews_df['Province'].describe()
# Out:
# count         137229
# unique           446
# top       California
# freq           44355
# Name: Province, dtype: object

# %%
reviews_df['Region_1'].describe()
# Out:
# count          114392
# unique           1197
# top       Napa Valley
# freq             6190
# Name: Region_1, dtype: object

# %%
reviews_df['Region_2'].describe()
# Out:
# count             60703
# unique               18
# top       Central Coast
# freq              12987
# Name: Region_2, dtype: object

# %%
reviews_df['Variety'].describe()
# Out:
# count         137229
# unique           619
# top       Chardonnay
# freq           13775
# Name: Variety, dtype: object

# %%
reviews_df['Winery'].describe()
# Out:
# count              137229
# unique              13851
# top       Williams Selyem
# freq                  371
# Name: Winery, dtype: object

# %%
#Finding the standard deviation of the dataframe
reviews_df.std()
# Out:
# Points     3.221507
# Price     36.319116
# dtype: float64

# %%
#Performing further analysis on the country column of the dataset
#1. Finding the total amount of Countries featured in the reviews
total_countries = reviews_df['Country'].unique()
print('Number of Countries reviewed: {}'.format(len(total_countries)))
# Out:
# Number of Countries reviewed: 46

# %%
#Displaying the countries in the review
unique_countries = reviews_df['Country'].unique()
print('Total amount of unique countries: {}'.format(len(unique_countries)))
print(unique_countries)
# Out:
# Total amount of unique countries: 46
# ['Spain' 'US' 'France' 'Italy' 'New Zealand' 'Bulgaria' 'Argentina'
#  'Australia' 'Portugal' 'Israel' 'South Africa' 'Greece' 'Chile' 'Morocco'
#  'Romania' 'Germany' 'Canada' 'Moldova' 'Hungary' 'Austria' 'Croatia'
#  'Slovenia' 'India' 'Turkey' 'Macedonia' 'Lebanon' 'Serbia' 'Uruguay'
#  'Switzerland' 'Albania' 'Bosnia and Herzegovina' 'Brazil' 'Cyprus'
#  'Lithuania' 'Japan' 'China' 'South Korea' 'Ukraine' 'England' 'Mexico'
#  'Georgia' 'Montenegro' 'Luxembourg' 'Slovakia' 'Czech Republic'
#  'US-France']

# %%
#Finding total wine reviews per country for the top 25
review_totals_by_country = reviews_df['Country'].value_counts().head(25)
print('Total amount of Reviews submitted for each country: \n')
print(review_totals_by_country)
# Out:
# Total amount of Reviews submitted for each country:
#
# US              62138
# Italy           18784
# France          14785
# Spain            8160
# Chile            5766
# Argentina        5587
# Australia        4894
# Portugal         4176
# New Zealand      3070
# Austria          2483
# Germany          2347
# South Africa     2237
# Greece            872
# Israel            610
# Hungary           230
# Canada            194
# Romania           139
# Uruguay            85
# Croatia            83
# Slovenia           81
# Bulgaria           77
# Moldova            71
# Mexico             63
# Turkey             50
# Georgia            43
# Name: Country, dtype: int64

# %%
#Grouping country by the most common Variety reviewed (first ten)
reviews_df.groupby('Country').Variety.max().head(10)
# Out:
# Country
# Albania                       Kallmet
# Argentina                 White Blend
# Australia                   Zinfandel
# Austria                      Zweigelt
# Bosnia and Herzegovina         Vranec
# Brazil                         Tannat
# Bulgaria                  White Blend
# Canada                    White Blend
# Chile                     White Blend
# China                     White Blend
# Name: Variety, dtype: object

# %% [markdown]
# # Aggregate Functions

# %%
#Grouping points per country - in terms of count, min, max points
reviews_df.groupby(['Country']).Points.agg([len, min, max])
# Out:
#                           len  min  max
# Country
# Albania                     2   88   88
# Argentina                5587   80   97
# Australia                4894   80  100
# Austria                  2483   81   98
# Bosnia and Herzegovina      4   83   88
# Brazil                     25   81   88
# Bulgaria                   77   80   90
# Canada                    194   82   93
# Chile                    5766   80   95
# China                       3   82   82
# Croatia                    83   81   91
# Cyprus                     31   80   89
# Czech Republic              6   85   87
# England                     8   91   94
# France                  14785   80  100
# Georgia                    43   81   92
# Germany                  2347   80   97
# Greece                    872   80   92
# Hungary                   230   80   96
# India                       8   82   91
# Israel                    610   80   93
# Italy                   18784   80  100
# Japan                       2   85   85
# Lebanon                    37   81   91
# Lithuania                   8   84   85
# Luxembourg                  9   86   88
# Macedonia                  16   81   89
# Mexico                     63   80   92
# Moldova                    71   81   90
# Montenegro                  2   82   82
# Morocco                    12   82   93
# New Zealand              3070   80   94
# Portugal                 4176   80   99
# Romania                   139   80   92
# Serbia                     14   86   89
# Slovakia                    3   82   87
# Slovenia                   81   82   92
# South Africa             2237   80   95
# South Korea                 4   81   82
# Spain                    8160   80   98
# Switzerland                 4   83   90
# Turkey                     50   84   92
# US                      62138   80  100
# US-France                   1   88   88
# Ukraine                     5   83   86
# Uruguay                    85   80   90

# %% [markdown]
# # Custom Grouping

# %%
#Sum reviews per Country + Region
reviews_df.Country + " - " + reviews_df.Region_1
# Out:
# Index
# 1                      Spain - Toro
# 2               US - Knights Valley
# 3            US - Willamette Valley
# 4                   France - Bandol
# 5                      Spain - Toro
#                     ...
# 150925    Italy - Fiano di Avellino
# 150926           France - Champagne
# 150927    Italy - Fiano di Avellino
# 150928           France - Champagne
# 150929           Italy - Alto Adige
# Length: 137229, dtype: object

# %%
#Most expensive wine
max_price = reviews_df['Price'].max()
print('The most expensive wine in all the reviews cost ${:.2f}'.format(max_price))
# Out:
# The most expensive wine in all the reviews cost $2300.00

# %%
#Displaying the country with the most expensive wine price tag
reviews_df[reviews_df['Price'] == 2300]
# Out:
#       Country                                        Description Designation  \
# Index
# 34920  France  A big, powerful wine that sums up the richness...         NaN
#
#        Points   Price  Province  Region_1 Region_2                   Variety  \
# Index
# 34920      99  2300.0  Bordeaux  Pauillac      NaN  Bordeaux-style Red Blend
#
#                Winery
# Index
# 34920  Château Latour

# %%
#Finding the average wine cost
avg_price = reviews_df['Price'].mean()
print('The average bottle in the review cost ${:.2f} USD'.format(avg_price))
# Out:
# The average bottle in the review cost $33.13 USD

# %%
#Finding the cheapest wine cost
min_price = reviews_df['Price'].min()
print('The cheapest bottle in the review cost ${:.2f} USD'.format(min_price))
# Out:
# The cheapest bottle in the review cost $4.00 USD

# %%
#Displaying the cheapest wines in the review
reviews_df[reviews_df['Price'] == 4.0]
# Out:
#           Country                                        Description  \
# Index
# 1858           US  Sweet and fruity, this canned wine feels soft ...
# 25645          US  There's a lot going on in this Merlot, which i...
# 34415       Spain  This opens with standard cherry and berry arom...
# 34682       Spain  Nice on the nose, this has a leafy note and a ...
# 36716   Argentina  Crimson in color but also translucent, with a ...
# 48655          US  There's a lot going on in this Merlot, which i...
# 73417     Romania  Notes of sun-dried hay and green flower highli...
# 80185          US  There's a lot going on in this Merlot, which i...
# 90546   Argentina  Clean as anyone should reasonably expect given...
# 91766   Argentina  Crimson in color but also translucent, with a ...
# 99045    Portugal  This is a ripe-fruited wine, rich with dried f...
# 102035      Spain  This opens with standard cherry and berry arom...
# 102332      Spain  Nice on the nose, this has a leafy note and a ...
# 114167         US  Easy, simple peach and strawberry flavors are ...
# 118347         US  Light and earthy, this wine-in-a-box is clean ...
# 119285         US  Packaged in a cute yellow recyclable Tetrapak,...
# 119295         US  A good everyday Merlot, dry and rich in tannin...
# 126595         US  There's a lot going on in this Merlot, which i...
#
#             Designation  Points  Price          Province    Region_1  \
# Index
# 1858            Unoaked      83    4.0        California  California
# 25645               NaN      86    4.0        California  California
# 34415               NaN      84    4.0           Levante       Yecla
# 34682    Estate Bottled      84    4.0           Levante       Yecla
# 36716               Red      84    4.0  Mendoza Province     Mendoza
# 48655               NaN      86    4.0        California  California
# 73417           UnWineD      86    4.0   Viile Timisului         NaN
# 80185               NaN      86    4.0        California  California
# 90546               NaN      85    4.0  Mendoza Province     Mendoza
# 91766               Red      84    4.0  Mendoza Province     Mendoza
# 99045          Toutalga      86    4.0        Alentejano         NaN
# 102035              NaN      84    4.0           Levante       Yecla
# 102332   Estate Bottled      84    4.0           Levante       Yecla
# 114167  White Zinfandel      83    4.0        California  California
# 118347              NaN      84    4.0        California  California
# 119285              NaN      84    4.0        California  California
# 119295              NaN      84    4.0        California  California
# 126595              NaN      86    4.0        California  California
#
#                 Region_2             Variety                Winery
# Index
# 1858    California Other          Chardonnay          Pam's Cuties
# 25645   California Other              Merlot                Bandit
# 34415                NaN  Cabernet Sauvignon              Terrenal
# 34682                NaN         Tempranillo              Terrenal
# 36716                NaN        Malbec-Syrah             Broke Ass
# 48655   California Other              Merlot                Bandit
# 73417                NaN        Pinot Grigio         Cramele Recas
# 80185   California Other              Merlot                Bandit
# 90546                NaN              Malbec         Toca Diamonte
# 91766                NaN        Malbec-Syrah             Broke Ass
# 99045                NaN      Portuguese Red  Herdade dos Machados
# 102035               NaN  Cabernet Sauvignon              Terrenal
# 102332               NaN         Tempranillo              Terrenal
# 114167  California Other           Zinfandel            Round Hill
# 118347  California Other  Cabernet Sauvignon                Bandit
# 119285  California Other          Chardonnay                Bandit
# 119295  California Other              Merlot                Bandit
# 126595  California Other              Merlot                Bandit

# %%
#Wine Points
reviews_df.Points.describe()
# Out:
# count    137229.000000
# mean         87.787975
# std           3.221507
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          90.000000
# max         100.000000
# Name: Points, dtype: float64

# %%
#Variety
#Finding Most reviewed wine per variety (Top 25)
reviews_df['Variety'].value_counts().head(25)
# Out:
# Chardonnay                       13775
# Pinot Noir                       13625
# Cabernet Sauvignon               12670
# Red Blend                         9377
# Sauvignon Blanc                   6054
# Syrah                             5667
# Riesling                          5212
# Merlot                            4987
# Bordeaux-style Red Blend          4545
# Zinfandel                         3794
# Malbec                            3085
# Sangiovese                        2879
# White Blend                       2554
# Tempranillo                       2525
# Rosé                              2461
# Shiraz                            1945
# Sparkling Blend                   1820
# Portuguese Red                    1812
# Nebbiolo                          1529
# Rhône-style Red Blend             1455
# Cabernet Franc                    1310
# Corvina, Rondinella, Molinara     1292
# Pinot Gris                        1275
# Pinot Grigio                      1270
# Viognier                          1255
# Name: Variety, dtype: int64

# %%
#Finding number of unique wine varieties in the review
unique_wines = reviews_df['Variety'].unique()
print('Unique wine varieties in the reviews: \n{}'.format(len(unique_wines)))
# Out:
# Unique wine varieties in the reviews:
# 619

# %%
#Top three wines reviewed (out of the 619 total)
reviews_df['Variety'].value_counts().head(3)
# Out:
# Chardonnay            13775
# Pinot Noir            13625
# Cabernet Sauvignon    12670
# Name: Variety, dtype: int64

# %%
#Grouping varieties by country
reviews_df.groupby('Country').Variety.max().head(10)
# Out:
# Country
# Albania                       Kallmet
# Argentina                 White Blend
# Australia                   Zinfandel
# Austria                      Zweigelt
# Bosnia and Herzegovina         Vranec
# Brazil                         Tannat
# Bulgaria                  White Blend
# Canada                    White Blend
# Chile                     White Blend
# China                     White Blend
# Name: Variety, dtype: object

# %%
# %%time
# Plotting Points and Price grouped by Variety (only ten visible)
reviews_df.groupby(['Points', 'Variety']).apply(lambda reviews_df:
reviews_df.loc[reviews_df.Points.argmax()]).head(10).plot.bar()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <timed eval> in <module>
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     857         with option_context("mode.chained_assignment", None):
#     858             try:
# --> 859                 result = self._python_apply_general(f, self._selected_obj)
#     860             except TypeError:
#     861                 # gh-20949
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f, data)
#     890             data after applying f
#     891         """
# --> 892         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     893
#     894         return self._wrap_applied_output(
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     211             # group might be modified
#     212             group_axes = group.axes
# --> 213             res = f(group)
#     214             if not _is_indexed_like(res, group_axes):
#     215                 mutated = True
#
# <timed eval> in <lambda>(reviews_df)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3489             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3490         else:
# -> 3491             loc = self.index.get_loc(key)
#    3492
#    3493             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 0

# %%
# %%time
# Group Point and Price values by Country and Variety
reviews_df.groupby(['Country', 'Variety']).apply(lambda reviews_df:
reviews_df.loc[reviews_df.Points.argmax()]).head(10).plot.bar()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <timed eval> in <module>
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     857         with option_context("mode.chained_assignment", None):
#     858             try:
# --> 859                 result = self._python_apply_general(f, self._selected_obj)
#     860             except TypeError:
#     861                 # gh-20949
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f, data)
#     890             data after applying f
#     891         """
# --> 892         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     893
#     894         return self._wrap_applied_output(
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     211             # group might be modified
#     212             group_axes = group.axes
# --> 213             res = f(group)
#     214             if not _is_indexed_like(res, group_axes):
#     215                 mutated = True
#
# <timed eval> in <lambda>(reviews_df)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3489             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3490         else:
# -> 3491             loc = self.index.get_loc(key)
#    3492
#    3493             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 0

# %% [markdown]
# # Searching for wines by specific countries

# %%
#Get wine from Argentina
#Sorting top ten by points
argentina_top_ten = reviews_df[reviews_df['Country'].str.match('Argentina')]
argentina_top_ten.sort_values('Points', ascending = False).head(10)
# Out:
#           Country                                        Description  \
# Index
# 116691  Argentina  If the color doesn't tell the full story, the ...
# 121311  Argentina  If the color doesn't tell the full story, the ...
# 65331   Argentina  If the color doesn't tell the full story, the ...
# 107804  Argentina  This blend from the Nicasia and Adrianna viney...
# 63766   Argentina  Features intoxicating pastry, blueberry, cola ...
# 107806  Argentina  Features intoxicating pastry, blueberry, cola ...
# 63764   Argentina  This blend from the Nicasia and Adrianna viney...
# 83001   Argentina  This wine takes you on a trip to an outer wine...
# 130756  Argentina  Features intoxicating pastry, blueberry, cola ...
# 130754  Argentina  This blend from the Nicasia and Adrianna viney...
#
#                           Designation  Points  Price          Province  \
# Index
# 116691               Nicasia Vineyard      97  120.0  Mendoza Province
# 121311               Nicasia Vineyard      97  120.0  Mendoza Province
# 65331                Nicasia Vineyard      97  120.0  Mendoza Province
# 107804                      Argentino      96  123.0  Mendoza Province
# 63766                Nicasia Vineyard      96  123.0  Mendoza Province
# 107806               Nicasia Vineyard      96  123.0  Mendoza Province
# 63764                       Argentino      96  123.0  Mendoza Province
# 83001   Gran Corte Las Divas Vineyard      96   50.0  Mendoza Province
# 130756               Nicasia Vineyard      96  123.0  Mendoza Province
# 130754                      Argentino      96  123.0  Mendoza Province
#
#          Region_1 Region_2                   Variety                Winery
# Index
# 116691    Mendoza      NaN                    Malbec  Bodega Catena Zapata
# 121311    Mendoza      NaN                    Malbec  Bodega Catena Zapata
# 65331     Mendoza      NaN                    Malbec  Bodega Catena Zapata
# 107804    Mendoza      NaN                    Malbec  Bodega Catena Zapata
# 63766     Mendoza      NaN                    Malbec  Bodega Catena Zapata
# 107806    Mendoza      NaN                    Malbec  Bodega Catena Zapata
# 63764     Mendoza      NaN                    Malbec  Bodega Catena Zapata
# 83001   Tupungato      NaN  Bordeaux-style Red Blend                Riglos
# 130756    Mendoza      NaN                    Malbec  Bodega Catena Zapata
# 130754    Mendoza      NaN                    Malbec  Bodega Catena Zapata

# %%
#Finding the wines that had a perfect score rating of 100 (on a scale of 1-100)
#Creating a new dataframe for the perfect scores records
perfect_scores_df = reviews_df[reviews_df['Points'] == 100]
perfect_scores_df
# Out:
#           Country                                        Description  \
# Index
# 2145       France  Full of ripe fruit, opulent and concentrated, ...
# 19354          US  In a stunning lineup of Cayuse Syrahs, the En ...
# 19355   Australia  Not a Cellar Selection in the traditional sens...
# 24151       Italy  A perfect wine from a classic vintage, the 200...
# 26296      France  A wine that has created its own universe. It h...
# 28954       Italy  This small, family-run estate in the heart of ...
# 41521       Italy  A perfect wine from a classic vintage, the 200...
# 51886      France  A wine that has created its own universe. It h...
# 78004       Italy  This small, family-run estate in the heart of ...
# 83536      France  A wine that has created its own universe. It h...
# 84034          US  In a stunning lineup of Cayuse Syrahs, the En ...
# 84035   Australia  Not a Cellar Selection in the traditional sens...
# 89399          US  Tasted in a flight of great and famous Napa wi...
# 92916          US  A perfect score has to be considered in the co...
# 98647          US  A spectacular Pinot Noir, but a very young one...
# 111087      Italy  Thick as molasses and dark as caramelized brow...
# 114272         US  Impossibly aromatic. Hard to imagine greater c...
# 119194         US  In a stunning lineup of Cayuse Syrahs, the En ...
# 119195  Australia  Not a Cellar Selection in the traditional sens...
# 119521      Italy  A perfect wine from a classic vintage, the 200...
# 122767         US  A spectacular Pinot Noir, but a very young one...
# 137099         US  Tasted in a flight of great and famous Napa wi...
# 138867      Italy  Thick as molasses and dark as caramelized brow...
# 143522         US  Impossibly aromatic. Hard to imagine greater c...
#
#                    Designation  Points   Price    Province  \
# Index
# 2145                       NaN     100   848.0    Bordeaux
# 19354   En Chamberlin Vineyard     100    65.0      Oregon
# 19355                     Rare     100   300.0    Victoria
# 24151                  Masseto     100   460.0     Tuscany
# 26296           Clos du Mesnil     100  1400.0   Champagne
# 28954         Guado de' Gemoli     100   195.0     Tuscany
# 41521                  Masseto     100   460.0     Tuscany
# 51886           Clos du Mesnil     100  1400.0   Champagne
# 78004         Guado de' Gemoli     100   195.0     Tuscany
# 83536           Clos du Mesnil     100  1400.0   Champagne
# 84034   En Chamberlin Vineyard     100    65.0      Oregon
# 84035                     Rare     100   300.0    Victoria
# 89399                      NaN     100   200.0  California
# 92916          Hillside Select     100   215.0  California
# 98647   Litton Estate Vineyard     100   100.0  California
# 111087       Occhio di Pernice     100   210.0     Tuscany
# 114272                Red Wine     100   245.0  California
# 119194  En Chamberlin Vineyard     100    65.0      Oregon
# 119195                    Rare     100   300.0    Victoria
# 119521                 Masseto     100   460.0     Tuscany
# 122767  Litton Estate Vineyard     100   100.0  California
# 137099                     NaN     100   200.0  California
# 138867       Occhio di Pernice     100   210.0     Tuscany
# 143522                Red Wine     100   245.0  California
#
#                           Region_1      Region_2                     Variety  \
# Index
# 2145                Pessac-Léognan           NaN  Bordeaux-style White Blend
# 19354      Walla Walla Valley (OR)  Oregon Other                       Syrah
# 19355                   Rutherglen           NaN                      Muscat
# 24151                      Toscana           NaN                      Merlot
# 26296                    Champagne           NaN                  Chardonnay
# 28954           Bolgheri Superiore           NaN                   Red Blend
# 41521                      Toscana           NaN                      Merlot
# 51886                    Champagne           NaN                  Chardonnay
# 78004           Bolgheri Superiore           NaN                   Red Blend
# 83536                    Champagne           NaN                  Chardonnay
# 84034      Walla Walla Valley (OR)  Oregon Other                       Syrah
# 84035                   Rutherglen           NaN                      Muscat
# 89399                  Napa Valley          Napa          Cabernet Sauvignon
# 92916          Stags Leap District          Napa          Cabernet Sauvignon
# 98647         Russian River Valley        Sonoma                  Pinot Noir
# 111087  Vin Santo di Montepulciano           NaN            Prugnolo Gentile
# 114272                  Rutherford          Napa              Cabernet Blend
# 119194     Walla Walla Valley (OR)  Oregon Other                       Syrah
# 119195                  Rutherglen           NaN                      Muscat
# 119521                     Toscana           NaN                      Merlot
# 122767        Russian River Valley        Sonoma                  Pinot Noir
# 137099                 Napa Valley          Napa          Cabernet Sauvignon
# 138867  Vin Santo di Montepulciano           NaN            Prugnolo Gentile
# 143522                  Rutherford          Napa              Cabernet Blend
#
#                              Winery
# Index
# 2145             Château Haut-Brion
# 19354                        Cayuse
# 19355   Chambers Rosewood Vineyards
# 24151         Tenuta dell'Ornellaia
# 26296                          Krug
# 28954            Giovanni Chiappini
# 41521         Tenuta dell'Ornellaia
# 51886                          Krug
# 78004            Giovanni Chiappini
# 83536                          Krug
# 84034                        Cayuse
# 84035   Chambers Rosewood Vineyards
# 89399                     Cardinale
# 92916                        Shafer
# 98647               Williams Selyem
# 111087                   Avignonesi
# 114272                        Sloan
# 119194                       Cayuse
# 119195  Chambers Rosewood Vineyards
# 119521        Tenuta dell'Ornellaia
# 122767              Williams Selyem
# 137099                    Cardinale
# 138867                   Avignonesi
# 143522                        Sloan

# %%
#Shape of the dataframe (showing number of records in the dataframe)
perfect_scores_df.shape
# Out:
# (24, 10)

# %%
#Counting perfect scores per country
perfect_scores_df['Country'].value_counts()
# Out:
# US           10
# Italy         7
# France        4
# Australia     3
# Name: Country, dtype: int64

# %%
#Analyzing range in price for perfect score wines by country
perfect_scores_df.groupby(['Country']).Price.agg([len, min, max])
# Out:
#             len    min     max
# Country
# Australia   3.0  300.0   300.0
# France      4.0  848.0  1400.0
# Italy       7.0  195.0   460.0
# US         10.0   65.0   245.0

# %% [markdown]
# # 2.0 Visualizations

# %% [markdown]
# Styling(appearance)

# %%
#Setting the parameters for appearance
# %config InlineBackend.figure_format = 'retina'
sns.set() #revert to matplotlib defaults
plt.rcParams['figure.figsize'] = (9,6)
plt.rcParams['axes.labelpad'] = 10
sns.set_style('darkgrid')
#sns.set_palette('Reds')
#sns.set_context('poster', font_scale = 1.0)

# %%
x = reviews_df.index
y = reviews_df['Price']

# %%
# %%time
#Matplotlib to show random order by price
plt.plot(reviews_df.index, reviews_df['Price'])
# Out:
# Wall time: 538 ms

# %%
#Province Totals
fig,ax = plt.subplots(figsize = (14,6))
reviews_df.groupby(reviews_df['Country'])['Price'].mean().plot.bar()
mean_price = reviews_df['Price'].mean(0)
reviews_df['Price'].fillna(mean_price)
# Out:
# Index
# 1         110.0
# 2          90.0
# 3          65.0
# 4          66.0
# 5          73.0
#           ...
# 150925     20.0
# 150926     27.0
# 150927     20.0
# 150928     52.0
# 150929     15.0
# Name: Price, Length: 137229, dtype: float64

# %%
#Creating plot labels
ax.set_xlabel('Country')
ax.set_ylabel('Mean Price')

#Creating the plot title
ax.set_title('Mean Price per Country')
ax.legend(bbox_to_anchor = (1,1), loc = 2, title = 'Price')

fig.tight_layout()

# %%
# %%time
#Finding the Province with the most reviews in the dataset
reviews_df['Province'].value_counts().head(10).plot.bar()
# Out:
# Wall time: 152 ms
# <AxesSubplot:>

# %%
#Working on California
#Finding out the most reviews California had
top_province = reviews_df['Province'].value_counts().head(1)
print('The province with the most reviews is {}'.format(top_province))
# Out:
# The province with the most reviews is California    44355
# Name: Province, dtype: int64

# %%
# %%time
# Bar plot - Percentage of reviews per top ten provinces
(reviews_df['Province'].value_counts().head(10) / len(reviews_df)).plot.bar()
# Out:
# Wall time: 159 ms
# <AxesSubplot:>

# %%
# %%time
# Bar plot - points/reviews
reviews_df['Points'].value_counts().sort_index().plot.bar()
# Out:
# Wall time: 409 ms
# <AxesSubplot:>

# %%
# %%time
# Line plot of points/reviews
reviews_df['Points'].value_counts().sort_index().plot.line()
# Out:
# Wall time: 209 ms
# <AxesSubplot:>

# %% [markdown]
# # Seaborn

# %% [markdown]
# Countplot

# %%
# %%time
# Countplot - Distribution of points and how many reviews
sns.countplot(reviews_df['Points'])
# Out:
# Wall time: 419 ms
# <AxesSubplot:xlabel='Points', ylabel='count'>

# %% [markdown]
# Kernel Density Estimation Plot

# %%
# %%time
# Jointplot
sns.jointplot(x='Price', y='Points', data=reviews_df[reviews_df['Price'] < 500])
# Out:
# Wall time: 2.29 s

# %%
# %%time
# Plotted price and point value KDE Chart
sns.kdeplot(reviews_df[reviews_df['Price']<50].loc[:,['Price','Points']].dropna().sample(5000))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed eval> in <module>
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, **kwargs)
#    1696     # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #
#    1697
# -> 1698     p = _DistributionPlotter(
#    1699         data=data,
#    1700         variables=_DistributionPlotter.get_semantics(locals()),
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in __init__(self, data, variables)
#     106     ):
#     107
# --> 108         super().__init__(data=data, variables=variables)
#     109
#     110     @property
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     909         # Construct a tidy plot DataFrame. This will convert a number of
#     910         # types automatically, aligning on index in case of pandas objects
# --> 911         plot_data = pd.DataFrame(plot_data)
#     912
#     913         # Reduce the variables dictionary to fields with valid data
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     385
#     386         if not indexes and not raw_lengths:
# --> 387             raise ValueError("If using all scalar values, you must pass an index")
#     388
#     389         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
# %%time
# Hex grid
sns.jointplot(x='Price', y='Points', data=reviews_df[reviews_df['Price'] < 100], kind='hex',
gridsize=20)
# Out:
# Wall time: 1.34 s

# %%
# %%time
# Hex gridcfor wines below 60.00
sns.jointplot(x='Price', y='Points', data=reviews_df[reviews_df['Price'] < 50], kind='hex',
gridsize=20)
# Out:
# Wall time: 1.14 s

# %% [markdown]
# Linear Regression Plot

# %%
# %%time
# Line of best fit (Linear regression)
ax = sns.regplot(x="Price", y="Points", data=reviews_df)
# Out:
# Wall time: 35.5 s

# %%
# %%time
# Zoomed in Linear Regression
ax = sns.regplot(x=reviews_df["Price"], y="Points", data=reviews_df, x_estimator=np.mean,
logx=True, truncate=True)
# Out:
# Wall time: 1min 28s
